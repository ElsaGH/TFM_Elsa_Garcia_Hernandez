# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile

# %%
zf = ZipFile('../Data/sim_av_patient.zip')
zf
# Out:
# <zipfile.ZipFile filename='../Data/sim_av_patient.zip' mode='r'>

# %%
csv = zf.open('sim_av_patient.csv')
csv
# Out:
# <zipfile.ZipExtFile name='sim_av_patient.csv' mode='r' compress_type=deflate>

# %%
df = pd.read_csv(csv)
df.head()
# Out:
#    PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A DEATHCAUSECODE_1B  \
# 0   10000001    2   810000001         A               NaN               NaN
# 1   10000002    2   810000002         Z               NaN               NaN
# 2   10000003    1   810000003         A               NaN               NaN
# 3   10000004    1   810000004         A               NaN               NaN
# 4   10000005    2   810000005       NaN               NaN               NaN
#
#   DEATHCAUSECODE_1C DEATHCAUSECODE_2 DEATHCAUSECODE_UNDERLYING  \
# 0               NaN              NaN                       NaN
# 1               NaN              NaN                       NaN
# 2               NaN              NaN                       NaN
# 3               NaN              NaN                       NaN
# 4               NaN              NaN                       NaN
#
#   DEATHLOCATIONCODE NEWVITALSTATUS VITALSTATUSDATE
# 0               NaN              A      2017-01-17
# ...

# %%
df.sample(5)
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 712007    50045023    2   850045023         A               NaN
# 277538    10282315    1   810282315         A               NaN
# 1031060  130001039    1   930001039         A               NaN
# 1175050  180002303    2   980002303         A               C19
# 812769    70010247    1   870010247         Z               NaN
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C DEATHCAUSECODE_2  \
# 712007                NaN               NaN              NaN
# 277538                NaN               NaN              NaN
# 1031060               NaN               NaN              NaN
# 1175050               NaN               NaN              NaN
# 812769                NaN               NaN              NaN
#
#         DEATHCAUSECODE_UNDERLYING DEATHLOCATIONCODE NEWVITALSTATUS  \
# 712007                        NaN               NaN              A
# 277538                        NaN               NaN              D
# ...

# %%
df.shape
# Out:
# (1322100, 12)

# %%
df.isna().sum()
# Out:
# PATIENTID                          0
# SEX                                0
# LINKNUMBER                         0
# ETHNICITY                     129851
# DEATHCAUSECODE_1A             991820
# DEATHCAUSECODE_1B            1224015
# DEATHCAUSECODE_1C            1303994
# DEATHCAUSECODE_2             1180118
# DEATHCAUSECODE_UNDERLYING     994190
# DEATHLOCATIONCODE             991719
# NEWVITALSTATUS                     0
# VITALSTATUSDATE                    0
# dtype: int64

# %%
df.count()
# Out:
# PATIENTID                    1322100
# SEX                          1322100
# LINKNUMBER                   1322100
# ETHNICITY                    1192249
# DEATHCAUSECODE_1A             330280
# DEATHCAUSECODE_1B              98085
# DEATHCAUSECODE_1C              18106
# DEATHCAUSECODE_2              141982
# DEATHCAUSECODE_UNDERLYING     327910
# DEATHLOCATIONCODE             330381
# NEWVITALSTATUS               1322100
# VITALSTATUSDATE              1322100
# dtype: int64

# %%
df.dtypes
# Out:
# PATIENTID                     int64
# SEX                           int64
# LINKNUMBER                    int64
# ETHNICITY                    object
# DEATHCAUSECODE_1A            object
# DEATHCAUSECODE_1B            object
# DEATHCAUSECODE_1C            object
# DEATHCAUSECODE_2             object
# DEATHCAUSECODE_UNDERLYING    object
# DEATHLOCATIONCODE            object
# NEWVITALSTATUS               object
# VITALSTATUSDATE              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322100 entries, 0 to 1322099
# Data columns (total 12 columns):
# PATIENTID                    1322100 non-null int64
# SEX                          1322100 non-null int64
# LINKNUMBER                   1322100 non-null int64
# ETHNICITY                    1192249 non-null object
# DEATHCAUSECODE_1A            330280 non-null object
# DEATHCAUSECODE_1B            98085 non-null object
# DEATHCAUSECODE_1C            18106 non-null object
# DEATHCAUSECODE_2             141982 non-null object
# DEATHCAUSECODE_UNDERLYING    327910 non-null object
# DEATHLOCATIONCODE            330381 non-null object
# NEWVITALSTATUS               1322100 non-null object
# VITALSTATUSDATE              1322100 non-null object
# dtypes: int64(3), object(9)
# memory usage: 121.0+ MB

# %%
df['LINKNUMBER'].nunique()
# Out:
# 1322100

# %%
print("The original dataset has data for %d patients" % len(df))
print("After removing duplicates, the dataset has data for %d patients" % len(df.drop_duplicates()))
print("There are no duplicates in the dataset")
# Out:
# The original dataset has data for 1322100 patients
# After removing duplicates, the dataset has data for 1322100 patients
# There are no duplicates in the dataset

# %%
df['NEWVITALSTATUS'].unique()
# Out:
# array(['A', 'D', 'X', 'Potential error: Px interacts after DoDeath',
#        'Potential error: Px traced alive after DoDeath but <2m',
#        'Potential error iro DoDeath',
#        'Potential error: Px treated after DoDeath',
#        'Potential error: Px traced alive after DoDeath > 2m',
#        'Potential error: Px diagnosed after DoDeath'], dtype=object)

# %%
df.groupby('NEWVITALSTATUS')['NEWVITALSTATUS'].count()
# Out:
# NEWVITALSTATUS
# A                                                         991776
# D                                                         296625
# Potential error iro DoDeath                                 1371
# Potential error: Px diagnosed after DoDeath                    3
# Potential error: Px interacts after DoDeath                29608
# Potential error: Px traced alive after DoDeath > 2m           23
# Potential error: Px traced alive after DoDeath but <2m       815
# Potential error: Px treated after DoDeath                    141
# X                                                           1738
# Name: NEWVITALSTATUS, dtype: int64

# %%
percentage_alive = np.mean(df['NEWVITALSTATUS'] == 'A') * 100
percentage_dead = np.mean(df['NEWVITALSTATUS'] == 'D') * 100
percentage_others = np.mean((df['NEWVITALSTATUS'] != 'A') & (df['NEWVITALSTATUS'] != 'D')) * 100
print("Percentage of patients classified as alive: %.2f" % percentage_alive)
print("Percentage of patients classified as dead: %.2f" % percentage_dead)
print("Percentage of patients classified as other: %.2f" % percentage_others)
# Out:
# Percentage of patients classified as alive: 75.02
# Percentage of patients classified as dead: 22.44
# Percentage of patients classified as other: 2.55

# %%
df.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    645472
# 2    676628
# Name: SEX, dtype: int64

# %%
list(df['ETHNICITY'].unique())
# Out:
# ['A',
#  'Z',
#  nan,
#  'B',
#  'X',
#  'S',
#  'C',
#  '0',
#  'J',
#  'R',
#  'N',
#  'P',
#  'H',
#  'G',
#  'L',
#  'D',
#  'M',
#  'F',
#  'K',
#  '8',
#  'E']

# %%
df.groupby('ETHNICITY')['ETHNICITY'].count()
# Out:
# ETHNICITY
# 0        565
# 8         41
# A    1040228
# B      11014
# C      38399
# D       1118
# E        543
# F        849
# G       1785
# H       9541
# J       5560
# K       1659
# L       5168
# M       8253
# N       5439
# P       2960
# R       2235
# S      11233
# X      10318
# Z      35341
# Name: ETHNICITY, dtype: int64

# %%
df.groupby(['ETHNICITY','SEX'])['SEX'].count()
# Out:
# ETHNICITY  SEX
# 0          1         280
#            2         285
# 8          1          21
#            2          20
# A          1      516046
#            2      524182
# B          1        5858
#            2        5156
# C          1       16834
#            2       21565
# D          1         439
#            2         679
# E          1         219
#            2         324
# F          1         327
#            2         522
# G          1         717
#            2        1068
# H          1        4251
#            2        5290
# J          1        2528
#            2        3032
# K          1         801
#            2         858
# L          1        2331
#            2        2837
# M          1        4378
#            2        3875
# N          1        2531
#            2        2908
# P          1        1452
#            2        1508
# R          1         823
#            2        1412
# S          1        5225
#            2        6008
# ...

# %%
df.columns
# Out:
# Index(['PATIENTID', 'SEX', 'LINKNUMBER', 'ETHNICITY', 'DEATHCAUSECODE_1A',
#        'DEATHCAUSECODE_1B', 'DEATHCAUSECODE_1C', 'DEATHCAUSECODE_2',
#        'DEATHCAUSECODE_UNDERLYING', 'DEATHLOCATIONCODE', 'NEWVITALSTATUS',
#        'VITALSTATUSDATE'],
#       dtype='object')

# %%
df.groupby('DEATHCAUSECODE_1A')['DEATHCAUSECODE_1A'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHCAUSECODE_1A
# C349    47786
# J189    15561
# C259    13568
# C798    13547
# J180    12394
# C159    10963
# C189     7287
# C509     6565
# C61      6485
# C719     6018
# Name: DEATHCAUSECODE_1A, dtype: int64

# %%
df.groupby('DEATHCAUSECODE_1B')['DEATHCAUSECODE_1B'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHCAUSECODE_1B
# C349    13072
# C159     2559
# C259     2491
# I259     2323
# J449     2201
# J189     2082
# C189     1899
# C61      1773
# C509     1722
# C679     1623
# Name: DEATHCAUSECODE_1B, dtype: int64

# %%
df.groupby('DEATHCAUSECODE_1C')['DEATHCAUSECODE_1C'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHCAUSECODE_1C
# C349    1295
# I259     432
# C679     390
# C259     357
# C920     345
# C61      341
# C189     331
# C159     314
# J449     295
# I251     274
# Name: DEATHCAUSECODE_1C, dtype: int64

# %%
df.groupby('DEATHCAUSECODE_2')['DEATHCAUSECODE_2'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHCAUSECODE_2
# J449    8450
# I259    5731
# F03     3442
# C61     3042
# C349    3038
# E119    2972
# I10     2824
# C509    2068
# R54     1830
# G309    1633
# Name: DEATHCAUSECODE_2, dtype: int64

# %%
df.groupby('DEATHCAUSECODE_UNDERLYING')['DEATHCAUSECODE_UNDERLYING'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHCAUSECODE_UNDERLYING
# C349    68766
# C259    17833
# C159    15526
# C61     11558
# C189    10897
# C509    10435
# C679     9055
# C800     8299
# C169     7708
# C719     7433
# Name: DEATHCAUSECODE_UNDERLYING, dtype: int64

# %%
df.groupby('DEATHLOCATIONCODE')['DEATHLOCATIONCODE'].count().sort_values(ascending=False).head(10)
# Out:
# DEATHLOCATIONCODE
# 1    138327
# 4     98681
# 2     40284
# X     28209
# 5     17025
# 6      7146
# 3       709
# Name: DEATHLOCATIONCODE, dtype: int64

# %%
df.groupby('NEWVITALSTATUS')['DEATHCAUSECODE_1A'].unique()
# Out:
# NEWVITALSTATUS
# A                                                         [nan, R688, I259, C170, R53, C442, C449, C798,...
# D                                                         [C241, nan, J189, I259, J180, C443, N19, R688,...
# Potential error iro DoDeath                               [nan, J189, J180, J22, C349, D619, I64, G309, ...
# Potential error: Px diagnosed after DoDeath                                                     [nan, C259]
# Potential error: Px interacts after DoDeath               [nan, C442, I259, C159, J22, C260,N390, C20,C7...
# Potential error: Px traced alive after DoDeath > 2m       [nan, C349, C798, C509,C780, C159, J690, C719,...
# Potential error: Px traced alive after DoDeath but <2m    [nan, I509, J441, C809, S271, J22, C509, C189,...
# Potential error: Px treated after DoDeath                 [nan, C798, C349, I64, C349,C80, J189, C80, J1...
# ...

# %%
df['VITALSTATUSDATE'].sort_values()
# Out:
# 177853    1900-01-01
# 16417     1900-01-01
# 254427    1900-01-01
# 289690    1900-01-01
# 254445    1900-01-01
#              ...
# 945278    2017-02-01
# 402261    2017-02-02
# 445143    2017-02-02
# 378337    2017-02-02
# 411414    2017-02-02
# Name: VITALSTATUSDATE, Length: 1322100, dtype: object

# %%
df['VITALSTATUSDATE'].replace('1900-01-01', np.nan, inplace=True)

# %%
df['VITALSTATUSDATE'].sort_values()
# Out:
# 637679     2013-01-02
# 768267     2013-01-02
# 894115     2013-01-02
# 1132195    2013-01-02
# 1107857    2013-01-02
#               ...
# 309547            NaN
# 328693            NaN
# 472862            NaN
# 538189            NaN
# 1192179           NaN
# Name: VITALSTATUSDATE, Length: 1322100, dtype: object

# %%
df[df['VITALSTATUSDATE'].isna()]
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 4320      10004393    2   810004393       NaN               NaN
# 16417     10016722    1   810016722         A               NaN
# 60739     10061820    1   810061820         A               NaN
# 72164     10073448    1   810073448       NaN               NaN
# 81067     10082496    1   810082496         A               NaN
# 86314     10087824    2   810087824       NaN               NaN
# 88667     10090212    1   810090212         A               NaN
# 126058    10128257    1   810128257         A               NaN
# 127644    10129874    2   810129874         A               NaN
# 142004    10144489    2   810144489         A               NaN
# 143191    10145698    2   810145698       NaN               NaN
# 143365    10145874    1   810145874       NaN               NaN
# 146526    10149095    2   810149095         A               NaN
# 158468    10161241    1   810161241         B               NaN
# ...

# %%
df['VITALSTATUSDATE'].isna().sum()
# Out:
# 31

# %%
list(df['DEATHCAUSECODE_1A'].unique())
# Out:
# [nan,
#  'R688',
#  'C241',
#  'I259',
#  'J189',
#  'C170',
#  'R53',
#  'C442',
#  'C449',
#  'C798',
#  'C859',
#  'R54',
#  'J181',
#  'A419',
#  'J180',
#  'C349',
#  'J22',
#  'N390',
#  'T71,X700',
#  'J690',
#  'R688,R54',
#  'G039',
#  'I500',
#  'C61',
#  'I64',
#  'I501',
#  'I613',
#  'K922',
#  'C189',
#  'C809',
#  'C259',
#  'D70,A419',
#  'G904',
#  'G309',
#  'C459',
#  'I269',
#  'C679',
#  'E876',
#  'J411',
#  'C169',
#  'I509',
#  'C443',
#  'C410',
#  'C80',
#  'J81',
#  'C760',
#  'C159',
#  'J958',
#  'F03',
#  'N19',
#  'C444',
#  'N185',
#  'C509',
#  'A419,J189',
#  'D649',
#  'I713',
#  'C541',
#  'K659',
#  'C851',
#  'C56',
#  'J449',
#  'C925',
#  'I629',
#  'R02',
#  'C809,C269',
#  'I312',
#  'C419',
#  'C719',
#  'C439',
#  'D430',
#  'J969',
#  'C221',
#  'S065',
#  'I714',
#  'C160',
#  'I219',
#  'R092',
#  'C833',
#  'I269,J189',
#  'R58',
#  'I469',
#  'C798,C800',
#  'I350,Y831,T828,Y839',
#  'C220',
#  'K559',
#  'K650',
#  'I619',
# ...

# %%
df[(df['NEWVITALSTATUS'] == 'A') & (df['DEATHCAUSECODE_1A'] == 'R688')]
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 6         10000007    1   810000007         A              R688
# 2051      10002088    2   810002088         A              R688
# 2127      10002166    2   810002166       NaN              R688
# 2663      10002715    2   810002715       NaN              R688
# 7036      10007168    2   810007168         A              R688
# ...            ...  ...         ...       ...               ...
# 1319651  220045928    2  1020045928         A              R688
# 1320385  220046729    1  1020046729         S              R688
# 1320965  220047361    1  1020047361         A              R688
# 1321233  220047644    2  1020047644         C              R688
# 1321820  220048270    2  1020048270         A              R688
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C    DEATHCAUSECODE_2  \
# 6                     NaN               NaN                J449
# 2051            C798,C800               NaN                K566
# ...

# %%
wrong_dead = df[(df['NEWVITALSTATUS'] == 'D') & (df['DEATHCAUSECODE_1A'].isna()) & (df['DEATHCAUSECODE_1B'].isna()) & (df['DEATHCAUSECODE_1C'].isna()) & (df['DEATHCAUSECODE_2'].isna()) & (df['DEATHCAUSECODE_UNDERLYING'].isna() & (df['DEATHLOCATIONCODE'].isna()))]
wrong_dead
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 24        10000026    1   810000026       NaN               NaN
# 54        10000057    1   810000057         A               NaN
# 56        10000059    1   810000059         A               NaN
# 79        10000082    2   810000082       NaN               NaN
# 88        10000091    1   810000091       NaN               NaN
# ...            ...  ...         ...       ...               ...
# 1322087  220048560    1  1020048560         A               NaN
# 1322092  220048567    1  1020048567         A               NaN
# 1322093  220048568    1  1020048568         A               NaN
# 1322097  220048572    1  1020048572         A               NaN
# 1322099  220048574    1  1020048574         S               NaN
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C DEATHCAUSECODE_2  \
# 24                    NaN               NaN              NaN
# 54                    NaN               NaN              NaN
# ...

# %%
correct_dead = df[(df['NEWVITALSTATUS'] == 'D') & ((df['DEATHCAUSECODE_1A'].notna()) | (df['DEATHCAUSECODE_1B'].notna()) | (df['DEATHCAUSECODE_1C'].notna()) | (df['DEATHCAUSECODE_2'].notna()) | (df['DEATHCAUSECODE_UNDERLYING'].notna()) | (df['DEATHLOCATIONCODE'].notna()))]
correct_dead
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 11        10000013    2   810000013         A              C241
# 55        10000058    1   810000058         A              J189
# 429       10000438    2   810000438         A              I259
# 581       10000590    2   810000590         A              J180
# 918       10000936    1   810000936         A              C443
# ...            ...  ...         ...       ...               ...
# 1322038  220048507    1  1020048507         A               NaN
# 1322047  220048517    1  1020048517         A               NaN
# 1322065  220048536    2  1020048536         A              D320
# 1322068  220048540    2  1020048540         A              J180
# 1322080  220048552    1  1020048552         A              C349
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C DEATHCAUSECODE_2  \
# 11                    NaN               NaN              NaN
# 55                    NaN              K562              F03
# ...

# %%
wrong_alive = df[(df['NEWVITALSTATUS'] == 'A') & ((df['DEATHCAUSECODE_1A'].notna()) | (df['DEATHCAUSECODE_1B'].notna()) | (df['DEATHCAUSECODE_1C'].notna()) | (df['DEATHCAUSECODE_2'].notna()) | (df['DEATHCAUSECODE_UNDERLYING'].notna()) | (df['DEATHLOCATIONCODE'].notna()))]
wrong_alive
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 6         10000007    1   810000007         A              R688
# 19        10000021    1   810000021       NaN              I259
# 121       10000124    1   810000124         A              C170
# 185       10000188    1   810000188       NaN               R53
# 201       10000205    2   810000205         A              C442
# ...            ...  ...         ...       ...               ...
# 1322085  220048558    2  1020048558         M               NaN
# 1322086  220048559    2  1020048559         A           B49,J22
# 1322088  220048561    1  1020048561         S              A419
# 1322089  220048563    2  1020048563         A              C920
# 1322091  220048566    2  1020048566         A               NaN
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C        DEATHCAUSECODE_2  \
# 6                     NaN               NaN                    J449
# ...

# %%
correct_alive = df[(df['NEWVITALSTATUS'] == 'A') & (df['DEATHCAUSECODE_1A'].isna()) & (df['DEATHCAUSECODE_1B'].isna()) & (df['DEATHCAUSECODE_1C'].isna()) & (df['DEATHCAUSECODE_2'].isna()) & (df['DEATHCAUSECODE_UNDERLYING'].isna()) & (df['DEATHLOCATIONCODE'].isna())]
correct_alive
# Out:
#          PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 0         10000001    2   810000001         A               NaN
# 1         10000002    2   810000002         Z               NaN
# 2         10000003    1   810000003         A               NaN
# 3         10000004    1   810000004         A               NaN
# 4         10000005    2   810000005       NaN               NaN
# ...            ...  ...         ...       ...               ...
# 1322090  220048564    1  1020048564         A               NaN
# 1322094  220048569    1  1020048569         A               NaN
# 1322095  220048570    1  1020048570         A               NaN
# 1322096  220048571    2  1020048571         A               NaN
# 1322098  220048573    2  1020048573         A               NaN
#
#         DEATHCAUSECODE_1B DEATHCAUSECODE_1C DEATHCAUSECODE_2  \
# 0                     NaN               NaN              NaN
# 1                     NaN               NaN              NaN
# ...

# %%
correct_dead_alive = correct_alive.merge(correct_dead, how='outer')
correct_dead_alive
# Out:
#         PATIENTID  SEX  LINKNUMBER ETHNICITY DEATHCAUSECODE_1A  \
# 0        10000001    2   810000001         A               NaN
# 1        10000002    2   810000002         Z               NaN
# 2        10000003    1   810000003         A               NaN
# 3        10000004    1   810000004         A               NaN
# 4        10000005    2   810000005       NaN               NaN
# ...           ...  ...         ...       ...               ...
# 982477  220048507    1  1020048507         A               NaN
# 982478  220048517    1  1020048517         A               NaN
# 982479  220048536    2  1020048536         A              D320
# 982480  220048540    2  1020048540         A              J180
# 982481  220048552    1  1020048552         A              C349
#
#        DEATHCAUSECODE_1B DEATHCAUSECODE_1C DEATHCAUSECODE_2  \
# 0                    NaN               NaN              NaN
# 1                    NaN               NaN              NaN
# ...

# %%
print("The original dataset had %d patients" % len(df))
print("The dataset with only correct data has %d patients" % len(correct_dead_alive))
print("A total of %d patients would be deleted" % (len(df) - len(correct_dead_alive)))
# Out:
# The original dataset had 1322100 patients
# The dataset with only correct data has 982482 patients
# A total of 339618 patients would be deleted

# %%
percentage_alive = np.mean(correct_dead_alive['NEWVITALSTATUS'] == 'A') * 100
percentage_dead = np.mean(correct_dead_alive['NEWVITALSTATUS'] == 'D') * 100
print("New percentage of patients classified as alive: %.2f" % percentage_alive)
print("New percentage of patients classified as dead: %.2f" % percentage_dead)
# Out:
# New percentage of patients classified as alive: 83.50
# New percentage of patients classified as dead: 16.50

# %%
#to decide what to do with the wrong patients
