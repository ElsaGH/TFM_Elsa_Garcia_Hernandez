# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile

# %%
pd.set_option('display.max_columns', None)

# %%
zf = ZipFile("../../Data/sim_sact_tumour.zip")
csv = zf.open("sim_sact_tumour.csv")
sim_sact_tumour = pd.read_csv(csv)
sim_sact_tumour.head()
# Out:
#    MERGED_TUMOUR_ID  MERGED_PATIENT_ID  CONSULTANT_SPECIALITY_CODE  \
# 0          10000001           10000235                       101.0
# 1          10000002           10000315                       101.0
# 2          10000003           10000337                       100.0
# 3          10000004           10000480                       303.0
# 4          10000005           10000533                       823.0
#
#   PRIMARY_DIAGNOSIS  MORPHOLOGY_CLEAN
# 0               C61           81403.0
# 1              C679           81403.0
# 2              C500               NaN
# 3              C829               NaN
# 4              D473               NaN

# %%
sim_sact_tumour.shape
# Out:
# (299727, 5)

# %%
print("The original dataset has data for %d patients" % len(sim_sact_tumour))
print("After removing duplicates, the dataset has data for %d patients" % len(sim_sact_tumour.drop_duplicates()))
print("There are no duplicates in the dataset")
# Out:
# The original dataset has data for 124217 patients
# After removing duplicates, the dataset has data for 124217 patients
# There are no duplicates in the dataset

# %%
sim_sact_tumour[sim_sact_tumour.groupby('MERGED_PATIENT_ID')['MERGED_PATIENT_ID'].transform('size') > 1].count()
# Out:
# MERGED_TUMOUR_ID              175510
# MERGED_PATIENT_ID             175510
# CONSULTANT_SPECIALITY_CODE    175506
# PRIMARY_DIAGNOSIS             175446
# MORPHOLOGY_CLEAN               86818
# dtype: int64

# %%
sim_sact_tumour[sim_sact_tumour.groupby('MERGED_PATIENT_ID')['MERGED_PATIENT_ID'].transform('size') == 1].count()
# Out:
# MERGED_TUMOUR_ID              124217
# MERGED_PATIENT_ID             124217
# CONSULTANT_SPECIALITY_CODE    124217
# PRIMARY_DIAGNOSIS             124173
# MORPHOLOGY_CLEAN               67420
# dtype: int64

# %%
sim_sact_tumour = sim_sact_tumour[sim_sact_tumour.groupby('MERGED_PATIENT_ID')['MERGED_PATIENT_ID'].transform('size') == 1]
sim_sact_tumour.head()
# Out:
#    MERGED_TUMOUR_ID  MERGED_PATIENT_ID  CONSULTANT_SPECIALITY_CODE  \
# 0          10000001           10000235                       101.0
# 1          10000002           10000315                       101.0
# 2          10000003           10000337                       100.0
# 3          10000004           10000480                       303.0
# 4          10000005           10000533                       823.0
#
#   PRIMARY_DIAGNOSIS  MORPHOLOGY_CLEAN
# 0               C61           81403.0
# 1              C679           81403.0
# 2              C500               NaN
# 3              C829               NaN
# 4              D473               NaN

# %%
sim_sact_tumour.shape
# Out:
# (124217, 5)

# %%
df = pd.read_csv("./Data/avpat_avtum_sactpat.csv", sep='^', index_col = 0)
df.head()
# Out:
#    PATIENTID SEX  LINKNUMBER ETHNICITY NEWVITALSTATUS VITALSTATUSDATE  \
# 0   10000724   M   810000724         A              A      2017-01-16
# 1   10000752   F   810000752         A              A      2017-01-16
# 2   10001050   F   810001050         A              A      2017-01-16
# 3   10001750   M   810001750         A              A      2017-01-16
# 4   10001824   F   810001824         S              A      2017-01-17
#
#    TUMOURID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 0  10335800        2013-09-08           NaN                 C50
# 1  10335805        2015-11-11          C504                 C50
# 2  10335823        2015-10-24           NaN                 C50
# 3  10335873        2014-09-23           NaN                 C50
# 4  10335879        2015-03-15           NaN                 C50
#
#    MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# 0          8130.0          Malignant      2      0      0         2B
# ...

# %%
df.shape
# Out:
# (103192, 35)

# %%
df = df.merge(sim_sact_tumour, left_on = 'MERGED_PATIENT_ID', right_on = 'MERGED_PATIENT_ID', how = 'left')

# %%
df.shape
# Out:
# (103192, 39)

# %%
df.head()
# Out:
#    PATIENTID SEX  LINKNUMBER ETHNICITY NEWVITALSTATUS VITALSTATUSDATE  \
# 0   10000724   M   810000724         A              A      2017-01-16
# 1   10000752   F   810000752         A              A      2017-01-16
# 2   10001050   F   810001050         A              A      2017-01-16
# 3   10001750   M   810001750         A              A      2017-01-16
# 4   10001824   F   810001824         S              A      2017-01-17
#
#    TUMOURID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 0  10335800        2013-09-08           NaN                 C50
# 1  10335805        2015-11-11          C504                 C50
# 2  10335823        2015-10-24           NaN                 C50
# 3  10335873        2014-09-23           NaN                 C50
# 4  10335879        2015-03-15           NaN                 C50
#
#    MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# 0          8130.0          Malignant      2      0      0         2B
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') > 1].count()
# Out:
# PATIENTID                     0
# SEX                           0
# LINKNUMBER                    0
# ETHNICITY                     0
# NEWVITALSTATUS                0
# VITALSTATUSDATE               0
# TUMOURID                      0
# DIAGNOSISDATEBEST             0
# SITE_ICD10_O2                 0
# SITE_ICD10_O2_3CHAR           0
# MORPH_ICD10_O2                0
# BEHAVIOUR_ICD10_O2            0
# T_BEST                        0
# N_BEST                        0
# M_BEST                        0
# STAGE_BEST                    0
# STAGE_BEST_SYSTEM             0
# GRADE                         0
# AGE                           0
# CREG_CODE                     0
# ER_STATUS                     0
# ER_SCORE                      0
# SCREENINGSTATUSFULL_CODE      0
# PR_STATUS                     0
# PR_SCORE                      0
# HER2_STATUS                   0
# CANCERCAREPLANINTENT          0
# PERFORMANCESTATUS             0
# CNS                           0
# ...

# %%
df.isna().sum()
# Out:
# PATIENTID                         0
# SEX                               0
# LINKNUMBER                        0
# ETHNICITY                      2572
# NEWVITALSTATUS                    0
# VITALSTATUSDATE                   0
# TUMOURID                          0
# DIAGNOSISDATEBEST                 0
# SITE_ICD10_O2                  1555
# SITE_ICD10_O2_3CHAR               0
# MORPH_ICD10_O2                   38
# BEHAVIOUR_ICD10_O2               53
# T_BEST                         9259
# N_BEST                        10588
# M_BEST                        41861
# STAGE_BEST                     9605
# STAGE_BEST_SYSTEM             16986
# GRADE                          6437
# AGE                               0
# CREG_CODE                         0
# ER_STATUS                     24817
# ER_SCORE                      61346
# SCREENINGSTATUSFULL_CODE      33307
# PR_STATUS                     54652
# PR_SCORE                      78644
# HER2_STATUS                   26491
# ...

# %%
df.count()
# Out:
# PATIENTID                     103192
# SEX                           103192
# LINKNUMBER                    103192
# ETHNICITY                     100620
# NEWVITALSTATUS                103192
# VITALSTATUSDATE               103192
# TUMOURID                      103192
# DIAGNOSISDATEBEST             103192
# SITE_ICD10_O2                 101637
# SITE_ICD10_O2_3CHAR           103192
# MORPH_ICD10_O2                103154
# BEHAVIOUR_ICD10_O2            103139
# T_BEST                         93933
# N_BEST                         92604
# M_BEST                         61331
# STAGE_BEST                     93587
# STAGE_BEST_SYSTEM              86206
# GRADE                          96755
# AGE                           103192
# CREG_CODE                     103192
# ER_STATUS                      78375
# ER_SCORE                       41846
# SCREENINGSTATUSFULL_CODE       69885
# PR_STATUS                      48540
# PR_SCORE                       24548
# ...

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# %%
df['PRIMARY_DIAGNOSIS'].value_counts()
# Out:
# C509    11627
# C504     2255
# C502      581
# C501      572
# C505      418
# C503      399
# C508      274
# C833      101
# C500       87
# D059       52
# C506       47
# D051       43
# C80        41
# C56        32
# C795       25
# C20        23
# C349       22
# C900       19
# C773       17
# C187       15
# C182       15
# C837       13
# C189       12
# C831       11
# C155       11
# C829       10
# D057       10
# C859       10
# C851       10
# C539       10
# C839        9
# C61         8
# C439        8
# C679        7
# C259        7
# C830        7
# C910        7
# C911        6
# C160        6
# C341        6
# C169        6
# C64         6
# C880        5
# C343        5
# C97         5
# C19         5
# C185        5
# C857        5
# C541        5
# C819        5
# C159        4
# C799        4
# C154        4
# D489        4
# C798        4
# C920        4
# C696        3
# D471        3
# D414        3
# D45         3
# C921        3
# C210        3
# ...

# %%
df['PRIMARY_DIAGNOSIS'].nunique()
# Out:
# 157

# %%
df.head()
# Out:
#    PATIENTID SEX  LINKNUMBER ETHNICITY NEWVITALSTATUS VITALSTATUSDATE  \
# 0   10000724   M   810000724         A              A      2017-01-16
# 1   10000752   F   810000752         A              A      2017-01-16
# 2   10001050   F   810001050         A              A      2017-01-16
# 3   10001750   M   810001750         A              A      2017-01-16
# 4   10001824   F   810001824         S              A      2017-01-17
#
#    TUMOURID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 0  10335800        2013-09-08           NaN                 C50
# 1  10335805        2015-11-11          C504                 C50
# 2  10335823        2015-10-24           NaN                 C50
# 3  10335873        2014-09-23           NaN                 C50
# 4  10335879        2015-03-15           NaN                 C50
#
#    MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# 0          8130.0          Malignant      2      0      0         2B
# ...

# %%
df.shape
# Out:
# (103192, 39)

# %%
df.to_csv('./Data/avpat_avtum_sactpat_sacttum.csv', sep='^')
