# %%
import pandas as pd
from zipfile import ZipFile

# %%
pd.set_option('display.max_columns', None)

# %%
zf = ZipFile("../../Data/sim_sact_patient.zip")
csv = zf.open("sim_sact_patient.csv")
sim_sact_patient = pd.read_csv(csv)
sim_sact_patient.head()
# Out:
#    MERGED_PATIENT_ID  LINK_NUMBER
# 0           10000087    810000087
# 1           10000235    810000235
# 2           10000283    810000283
# 3           10000315    810000315
# 4           10000337    810000337

# %%
sim_sact_patient.shape
# Out:
# (245938, 2)

# %%
sim_sact_patient.isna().sum()
# Out:
# MERGED_PATIENT_ID    0
# LINK_NUMBER          0
# dtype: int64

# %%
sim_sact_patient['LINK_NUMBER'].nunique()
# Out:
# 245938

# %%
print("The original dataset has data for %d patients" % len(sim_sact_patient))
print("After removing duplicates, the dataset has data for %d patients" % len(sim_sact_patient.drop_duplicates()))
print("There are no duplicates in the dataset")
# Out:
# The original dataset has data for 245938 patients
# After removing duplicates, the dataset has data for 245938 patients
# There are no duplicates in the dataset

# %%
df = pd.read_csv("./Data/avpat_avtum.csv", sep='^', index_col = 0)
df.head()
# Out:
#       PATIENTID SEX  LINKNUMBER ETHNICITY NEWVITALSTATUS VITALSTATUSDATE  \
# 624    10000724   M   810000724         A              A      2017-01-16
# 650    10000752   F   810000752         A              A      2017-01-16
# 913    10001050   F   810001050         A              A      2017-01-16
# 1543   10001750   M   810001750         A              A      2017-01-16
# 1613   10001824   F   810001824         S              A      2017-01-17
#
#       TUMOURID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 624   10335800        2013-09-08           NaN                 C50
# 650   10335805        2015-11-11          C504                 C50
# 913   10335823        2015-10-24           NaN                 C50
# 1543  10335873        2014-09-23           NaN                 C50
# 1613  10335879        2015-03-15           NaN                 C50
#
#       MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# ...

# %%
df.shape
# Out:
# (103192, 33)

# %%
df = df.merge(sim_sact_patient, left_on = 'LINKNUMBER', right_on = 'LINK_NUMBER', how = 'left')

# %%
df.head()
# Out:
#    PATIENTID SEX  LINKNUMBER ETHNICITY NEWVITALSTATUS VITALSTATUSDATE  \
# 0   10000724   M   810000724         A              A      2017-01-16
# 1   10000752   F   810000752         A              A      2017-01-16
# 2   10001050   F   810001050         A              A      2017-01-16
# 3   10001750   M   810001750         A              A      2017-01-16
# 4   10001824   F   810001824         S              A      2017-01-17
#
#    TUMOURID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 0  10335800        2013-09-08           NaN                 C50
# 1  10335805        2015-11-11          C504                 C50
# 2  10335823        2015-10-24           NaN                 C50
# 3  10335873        2014-09-23           NaN                 C50
# 4  10335879        2015-03-15           NaN                 C50
#
#    MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# 0          8130.0          Malignant      2      0      0         2B
# ...

# %%
df.shape
# Out:
# (103192, 35)

# %%
df.isna().sum()
# Out:
# PATIENTID                       0
# SEX                             0
# LINKNUMBER                      0
# ETHNICITY                    2572
# NEWVITALSTATUS                  0
# VITALSTATUSDATE                 0
# TUMOURID                        0
# DIAGNOSISDATEBEST               0
# SITE_ICD10_O2                1555
# SITE_ICD10_O2_3CHAR             0
# MORPH_ICD10_O2                 38
# BEHAVIOUR_ICD10_O2             53
# T_BEST                       9259
# N_BEST                      10588
# M_BEST                      41861
# STAGE_BEST                   9605
# STAGE_BEST_SYSTEM           16986
# GRADE                        6437
# AGE                             0
# CREG_CODE                       0
# ER_STATUS                   24817
# ER_SCORE                    61346
# SCREENINGSTATUSFULL_CODE    33307
# PR_STATUS                   54652
# PR_SCORE                    78644
# HER2_STATUS                 26491
# CANCERCAREPLANINTENT        56877
# ...

# %%
df.count()
# Out:
# PATIENTID                   103192
# SEX                         103192
# LINKNUMBER                  103192
# ETHNICITY                   100620
# NEWVITALSTATUS              103192
# VITALSTATUSDATE             103192
# TUMOURID                    103192
# DIAGNOSISDATEBEST           103192
# SITE_ICD10_O2               101637
# SITE_ICD10_O2_3CHAR         103192
# MORPH_ICD10_O2              103154
# BEHAVIOUR_ICD10_O2          103139
# T_BEST                       93933
# N_BEST                       92604
# M_BEST                       61331
# STAGE_BEST                   93587
# STAGE_BEST_SYSTEM            86206
# GRADE                        96755
# AGE                         103192
# CREG_CODE                   103192
# ER_STATUS                    78375
# ER_SCORE                     41846
# SCREENINGSTATUSFULL_CODE     69885
# PR_STATUS                    48540
# PR_SCORE                     24548
# HER2_STATUS                  76701
# CANCERCAREPLANINTENT         46315
# ...

# %%
df.shape
# Out:
# (103192, 35)

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') > 1].count()
# Out:
# PATIENTID                   0
# SEX                         0
# LINKNUMBER                  0
# ETHNICITY                   0
# NEWVITALSTATUS              0
# VITALSTATUSDATE             0
# TUMOURID                    0
# DIAGNOSISDATEBEST           0
# SITE_ICD10_O2               0
# SITE_ICD10_O2_3CHAR         0
# MORPH_ICD10_O2              0
# BEHAVIOUR_ICD10_O2          0
# T_BEST                      0
# N_BEST                      0
# M_BEST                      0
# STAGE_BEST                  0
# STAGE_BEST_SYSTEM           0
# GRADE                       0
# AGE                         0
# CREG_CODE                   0
# ER_STATUS                   0
# ER_SCORE                    0
# SCREENINGSTATUSFULL_CODE    0
# PR_STATUS                   0
# PR_SCORE                    0
# HER2_STATUS                 0
# CANCERCAREPLANINTENT        0
# PERFORMANCESTATUS           0
# CNS                         0
# ACE27                       0
# DATE_FIRST_SURGERY          0
# ...

# %%
df.to_csv('./Data/avpat_avtum_sactpat.csv', sep='^')
