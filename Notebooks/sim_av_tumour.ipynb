# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile

# %%
pd.set_option('display.max_columns', None)

# %%
zf = ZipFile('../Data/sim_av_tumour.zip')
csv = zf.open('sim_av_tumour.csv')
df = pd.read_csv(csv)
df.head()
# Out:
# /home/elsa/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5,6,8,9,17,18,20,22,26,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2 SITE_ICD10_O2_3CHAR  \
# 0  10000001   10000001        2015-11-06          C443                 C44
# 1  10000002   10000002        2015-10-06          C449                 C44
# 2  10000003   10000003        2013-01-30          C449                 C44
# 3  10000004   10000004        2015-09-15          C449                 C44
# 4  10000005   10000005        2014-11-01          C449                 C44
#
#   MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST M_BEST STAGE_BEST  \
# 0           8090                  3    NaN    NaN    NaN          ?
# 1           8090                  3    NaN    NaN    NaN          ?
# ...

# %%
df.sample(5)
# Out:
#           TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 458841    20108046   20108046        2013-04-10          C504
# 1257719  180014376  180014376        2015-04-01          D071
# 1172407  150018144  150018144        2015-12-22          C712
# 417702    20066226   20066226        2015-10-13          C509
# 130760    10133101   10133101        2014-03-31          C449
#
#         SITE_ICD10_O2_3CHAR MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST  \
# 458841                  C50           8500                  3     1b      0
# 1257719                 D07           8077                  2    NaN    NaN
# 1172407                 C71           9440                  3    NaN    NaN
# 417702                  C50           8500                  3    NaN    NaN
# 130760                  C44           8090                  3    NaN    NaN
#
#         M_BEST STAGE_BEST  STAGE_BEST_SYSTEM GRADE  AGE  SEX CREG_CODE  \
# ...

# %%
df.shape
# Out:
# (1402817, 34)

# %%
df.isna().sum()
# Out:
# TUMOURID                          0
# PATIENTID                         0
# DIAGNOSISDATEBEST                 0
# SITE_ICD10_O2                   514
# SITE_ICD10_O2_3CHAR             461
# MORPH_ICD10_O2                  513
# BEHAVIOUR_ICD10_O2              407
# T_BEST                       749764
# N_BEST                       856420
# M_BEST                       867135
# STAGE_BEST                       16
# STAGE_BEST_SYSTEM            730977
# GRADE                         62787
# AGE                               0
# SEX                               0
# CREG_CODE                         0
# LINKNUMBER                        0
# SCREENINGSTATUSFULL_CODE    1278256
# ER_STATUS                   1279117
# ER_SCORE                    1344907
# PR_STATUS                   1323601
# PR_SCORE                    1370032
# HER2_STATUS                 1294783
# CANCERCAREPLANINTENT         986954
# PERFORMANCESTATUS           1021537
# CNS                         1032895
# ...

# %%
df.count()
# Out:
# TUMOURID                    1402817
# PATIENTID                   1402817
# DIAGNOSISDATEBEST           1402817
# SITE_ICD10_O2               1402303
# SITE_ICD10_O2_3CHAR         1402356
# MORPH_ICD10_O2              1402304
# BEHAVIOUR_ICD10_O2          1402410
# T_BEST                       653053
# N_BEST                       546397
# M_BEST                       535682
# STAGE_BEST                  1402801
# STAGE_BEST_SYSTEM            671840
# GRADE                       1340030
# AGE                         1402817
# SEX                         1402817
# CREG_CODE                   1402817
# LINKNUMBER                  1402817
# SCREENINGSTATUSFULL_CODE     124561
# ER_STATUS                    123700
# ER_SCORE                      57910
# PR_STATUS                     79216
# PR_SCORE                      32785
# HER2_STATUS                  108034
# CANCERCAREPLANINTENT         415863
# PERFORMANCESTATUS            381280
# CNS                          369922
# ...

# %%
df.dtypes
# Out:
# TUMOURID                      int64
# PATIENTID                     int64
# DIAGNOSISDATEBEST            object
# SITE_ICD10_O2                object
# SITE_ICD10_O2_3CHAR          object
# MORPH_ICD10_O2               object
# BEHAVIOUR_ICD10_O2           object
# T_BEST                       object
# N_BEST                       object
# M_BEST                       object
# STAGE_BEST                   object
# STAGE_BEST_SYSTEM           float64
# GRADE                        object
# AGE                           int64
# SEX                           int64
# CREG_CODE                    object
# LINKNUMBER                    int64
# SCREENINGSTATUSFULL_CODE     object
# ER_STATUS                    object
# ER_SCORE                    float64
# PR_STATUS                    object
# PR_SCORE                    float64
# HER2_STATUS                  object
# CANCERCAREPLANINTENT         object
# PERFORMANCESTATUS            object
# CNS                          object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402817 entries, 0 to 1402816
# Data columns (total 34 columns):
# TUMOURID                    1402817 non-null int64
# PATIENTID                   1402817 non-null int64
# DIAGNOSISDATEBEST           1402817 non-null object
# SITE_ICD10_O2               1402303 non-null object
# SITE_ICD10_O2_3CHAR         1402356 non-null object
# MORPH_ICD10_O2              1402304 non-null object
# BEHAVIOUR_ICD10_O2          1402410 non-null object
# T_BEST                      653053 non-null object
# N_BEST                      546397 non-null object
# M_BEST                      535682 non-null object
# STAGE_BEST                  1402801 non-null object
# STAGE_BEST_SYSTEM           671840 non-null float64
# GRADE                       1340030 non-null object
# AGE                         1402817 non-null int64
# SEX                         1402817 non-null int64
# CREG_CODE                   1402817 non-null object
# ...

# %%
df['LINKNUMBER'].nunique()
# Out:
# 1322100

# %%
df.groupby('PATIENTID')['PATIENTID'].count().sort_values(ascending=False)
# Out:
# PATIENTID
# 60035351     6
# 210004664    6
# 70002509     5
# 150018274    5
# 220010521    5
#             ..
# 90003284     1
# 90003285     1
# 90003287     1
# 90003288     1
# 10000001     1
# Name: PATIENTID, Length: 1322100, dtype: int64

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') > 1].sort_values(by='PATIENTID')
# Out:
#           TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 15        10000017   10000017        2013-11-16          C443
# 329977    10335753   10000017        2013-11-16          C449
# 329978    10335754   10000018        2013-07-27          C508
# 16        10000018   10000018        2013-07-26          C443
# 24        10000026   10000026        2015-09-24          C444
# ...            ...        ...               ...           ...
# 1399445  220048504  220048504        2013-04-02          C940
# 1402606  220051898  220048528        2013-08-23          C542
# 1399466  220048528  220048528        2013-07-22           C33
# 1399473  220048535  220048535        2013-01-10          C930
# 1402607  220051899  220048535        2015-07-08          C679
#
#         SITE_ICD10_O2_3CHAR MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST  \
# 15                      C44           8090                  3    NaN    NaN
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 1].sort_values(by='PATIENTID')
# Out:
#           TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 0         10000001   10000001        2015-11-06          C443
# 1         10000002   10000002        2015-10-06          C449
# 2         10000003   10000003        2013-01-30          C449
# 3         10000004   10000004        2015-09-15          C449
# 4         10000005   10000005        2014-11-01          C449
# ...            ...        ...               ...           ...
# 1399504  220048570  220048570        2015-06-04          C930
# 1399505  220048571  220048571        2014-05-29          D150
# 1399506  220048572  220048572        2013-06-03          C700
# 1399507  220048573  220048573        2014-01-21          C940
# 1399508  220048574  220048574        2014-08-15          C930
#
#         SITE_ICD10_O2_3CHAR MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST  \
# 0                       C44           8090                  3    NaN    NaN
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 2].sort_values(by='PATIENTID')
# Out:
#           TUMOURID  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2  \
# 15        10000017   10000017        2013-11-16          C443
# 329977    10335753   10000017        2013-11-16          C449
# 329978    10335754   10000018        2013-07-27          C508
# 16        10000018   10000018        2013-07-26          C443
# 24        10000026   10000026        2015-09-24          C444
# ...            ...        ...               ...           ...
# 1399445  220048504  220048504        2013-04-02          C940
# 1402606  220051898  220048528        2013-08-23          C542
# 1399466  220048528  220048528        2013-07-22           C33
# 1402607  220051899  220048535        2015-07-08          C679
# 1399473  220048535  220048535        2013-01-10          C930
#
#         SITE_ICD10_O2_3CHAR MORPH_ICD10_O2 BEHAVIOUR_ICD10_O2 T_BEST N_BEST  \
# 15                      C44           8090                  3    NaN    NaN
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 6].nunique()
# Out:
# TUMOURID                    12
# PATIENTID                    2
# DIAGNOSISDATEBEST            6
# SITE_ICD10_O2               12
# SITE_ICD10_O2_3CHAR          8
# MORPH_ICD10_O2               7
# BEHAVIOUR_ICD10_O2           3
# T_BEST                       7
# N_BEST                       3
# M_BEST                       2
# STAGE_BEST                   6
# STAGE_BEST_SYSTEM            3
# GRADE                        4
# AGE                          8
# SEX                          1
# CREG_CODE                    3
# LINKNUMBER                   2
# SCREENINGSTATUSFULL_CODE     0
# ER_STATUS                    0
# ER_SCORE                     0
# PR_STATUS                    0
# PR_SCORE                     0
# HER2_STATUS                  0
# CANCERCAREPLANINTENT         2
# PERFORMANCESTATUS            3
# CNS                          4
# ACE27                        1
# GLEASON_PRIMARY              0
# GLEASON_SECONDARY            0
# GLEASON_TERTIARY             0
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 5].nunique()
# Out:
# TUMOURID                    55
# PATIENTID                   11
# DIAGNOSISDATEBEST           47
# SITE_ICD10_O2               37
# SITE_ICD10_O2_3CHAR         24
# MORPH_ICD10_O2              18
# BEHAVIOUR_ICD10_O2           7
# T_BEST                      10
# N_BEST                       5
# M_BEST                       3
# STAGE_BEST                  11
# STAGE_BEST_SYSTEM            3
# GRADE                        4
# AGE                         22
# SEX                          2
# CREG_CODE                    5
# LINKNUMBER                  11
# SCREENINGSTATUSFULL_CODE     1
# ER_STATUS                    0
# ER_SCORE                     0
# PR_STATUS                    0
# PR_SCORE                     0
# HER2_STATUS                  0
# CANCERCAREPLANINTENT         2
# PERFORMANCESTATUS            5
# CNS                          4
# ACE27                        1
# GLEASON_PRIMARY              1
# GLEASON_SECONDARY            1
# GLEASON_TERTIARY             0
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 4].nunique()
# Out:
# TUMOURID                    804
# PATIENTID                   201
# DIAGNOSISDATEBEST           497
# SITE_ICD10_O2               142
# SITE_ICD10_O2_3CHAR          76
# MORPH_ICD10_O2               76
# BEHAVIOUR_ICD10_O2           12
# T_BEST                       18
# N_BEST                       10
# M_BEST                        5
# STAGE_BEST                   18
# STAGE_BEST_SYSTEM             4
# GRADE                         5
# AGE                          69
# SEX                           2
# CREG_CODE                     8
# LINKNUMBER                  201
# SCREENINGSTATUSFULL_CODE      9
# ER_STATUS                     5
# ER_SCORE                      6
# PR_STATUS                     3
# PR_SCORE                      7
# HER2_STATUS                   3
# CANCERCAREPLANINTENT          5
# PERFORMANCESTATUS             7
# CNS                           6
# ACE27                         5
# GLEASON_PRIMARY               2
# GLEASON_SECONDARY             4
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 3].nunique()
# Out:
# TUMOURID                    11523
# PATIENTID                    3841
# DIAGNOSISDATEBEST            1086
# SITE_ICD10_O2                 362
# SITE_ICD10_O2_3CHAR           102
# MORPH_ICD10_O2                227
# BEHAVIOUR_ICD10_O2             13
# T_BEST                         28
# N_BEST                         14
# M_BEST                          7
# STAGE_BEST                     28
# STAGE_BEST_SYSTEM               5
# GRADE                           5
# AGE                            91
# SEX                             2
# CREG_CODE                       8
# LINKNUMBER                   3841
# SCREENINGSTATUSFULL_CODE       23
# ER_STATUS                       6
# ER_SCORE                        8
# PR_STATUS                       5
# PR_SCORE                        8
# HER2_STATUS                     5
# CANCERCAREPLANINTENT            6
# PERFORMANCESTATUS              10
# CNS                             9
# ACE27                           9
# ...

# %%
df[df.groupby('PATIENTID')['PATIENTID'].transform('size') == 2].nunique()
# Out:
# TUMOURID                    144756
# PATIENTID                    72378
# DIAGNOSISDATEBEST             1095
# SITE_ICD10_O2                  488
# SITE_ICD10_O2_3CHAR            113
# MORPH_ICD10_O2                 428
# BEHAVIOUR_ICD10_O2              15
# T_BEST                          38
# N_BEST                          20
# M_BEST                           8
# STAGE_BEST                      35
# STAGE_BEST_SYSTEM                7
# GRADE                            5
# AGE                            100
# SEX                              2
# CREG_CODE                        8
# LINKNUMBER                   72378
# SCREENINGSTATUSFULL_CODE        42
# ER_STATUS                        6
# ER_SCORE                         8
# PR_STATUS                        6
# PR_SCORE                         9
# HER2_STATUS                      5
# CANCERCAREPLANINTENT             6
# PERFORMANCESTATUS               10
# CNS                             11
# ACE27                           11
# ...

# %%
df[['DIAGNOSISDATEBEST','DATE_FIRST_SURGERY']].sort_values(by='DATE_FIRST_SURGERY').head(10)
# Out:
#         DIAGNOSISDATEBEST DATE_FIRST_SURGERY
# 387744         2013-01-30         1995-04-14
# 785794         2015-04-23         1998-01-27
# 967100         2015-02-04         2011-05-14
# 624565         2013-01-02         2011-05-31
# 1204731        2013-07-16         2011-06-08
# 974964         2015-03-07         2011-06-13
# 503963         2013-02-11         2011-09-27
# 584841         2013-05-01         2011-12-14
# 194104         2013-02-10         2011-12-18
# 213343         2013-02-12         2011-12-20
